# %%
import thinkdsp as td

x= td.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)
x

# %%
x.ts, x.ys
x.ys.shape
# Out:
# (10000,)

# %%
import matplotlib.pyplot as pl
pl.plot(x.ts, x.ys)

# %%
x.ys.max(), x.ys.mean(), x.ys.std()
# Out:
# (3.6878696645326468, 0.007664335771273308, 1.0041165405924564)

# %%
sx= x.make_spectrum()
sx.fs, sx.hs 
sx.hs.shape
# Out:
# (5001,)

# %%
sx.plot()

# %%
sx.plot_power()

# %%
Sx= sx.make_integrated_spectrum()
Sx.cs.shape
# Out:
# (5001,)

# %%
Sx.plot_power()

# %%
Sx.estimate_slope()
# Out:
# LinregressResult(slope=1.0209242644689829, intercept=-8.689264990491148, rvalue=0.9997372828931277, pvalue=0.0, stderr=0.0003310854990230887)

# %%
Sx.plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
Sx.estimate_slope()
# Out:
# LinregressResult(slope=1.0209242644689829, intercept=-8.689264990491148, rvalue=0.9997372828931277, pvalue=0.0, stderr=0.0003310854990230887)

# %%
y= x.cumsum()
x.ys.shape, y.ys.shape
# Out:
# ((10000,), (10000,))

# %%
y.plot()

# %%
y.ys.max(), y.ys.mean(), y.ys.std()
# Out:
# (97.81584467221958, 26.219089307688648, 31.688707652378863)

# %%
sy= y.make_spectrum()
sy.plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
sy.make_integrated_spectrum().plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
sy.make_integrated_spectrum().estimate_slope()
# Out:
# LinregressResult(slope=0.002041052968883087, intercept=-0.015902625111938264, rvalue=0.3492140537522857, pvalue=2.305904771239052e-143, stderr=7.74682860601232e-05)

# %%
z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()

# %%
z.make_spectrum().make_integrated_spectrum().estimate_slope()
# Out:
# LinregressResult(slope=0.00215853101298749, intercept=-0.016823529106453135, rvalue=0.41623764242439243, pvalue=8.829672257536938e-209, stderr=6.669678870770813e-05)

# %% [markdown]
# 10.slope z比較近似y
