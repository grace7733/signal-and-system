# %%
import thinkdsp as td

x= td.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)
x

# %%
x.ts, x.ys
x.ys.shape
# Out:
# (10000,)

# %%
import matplotlib.pyplot as pl
pl.plot(x.ts, x.ys)

# %%
x.ys.max(), x.ys.mean(), x.ys.std()
# Out:
# (3.8804848375714394, -0.006395804384318176, 0.9899638305394693)

# %%
sx= x.make_spectrum()
sx.fs, sx.hs 
sx.hs.shape
# Out:
# (5001,)

# %%
sx.plot()

# %%
sx.plot_power()

# %%
Sx= sx.make_integrated_spectrum()
Sx.cs.shape
# Out:
# (5001,)

# %%
Sx.plot_power()

# %%
Sx.estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-098356675605> in <module>
# ----> 1 Sx.estimate_slope()
#
# ~\Anaconda3\envs\grace87\lib\site-packages\thinkdsp.py in estimate_slope(self, low, high)
#     478         x = np.log(self.fs[low:high])
#     479         y = np.log(self.cs[low:high])
# --> 480         t = scipy.stats.linregress(x,y)
#     481         return t
#     482
#
# ~\Anaconda3\envs\grace87\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      93
#      94     if x.size == 0 or y.size == 0:
# ---> 95         raise ValueError("Inputs must not be empty.")
#      96
#      97     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
Sx.plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
Sx.estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-098356675605> in <module>
# ----> 1 Sx.estimate_slope()
#
# ~\Anaconda3\envs\grace87\lib\site-packages\thinkdsp.py in estimate_slope(self, low, high)
#     478         x = np.log(self.fs[low:high])
#     479         y = np.log(self.cs[low:high])
# --> 480         t = scipy.stats.linregress(x,y)
#     481         return t
#     482
#
# ~\Anaconda3\envs\grace87\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      93
#      94     if x.size == 0 or y.size == 0:
# ---> 95         raise ValueError("Inputs must not be empty.")
#      96
#      97     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
y= x.cumsum()
x.ys.shape, y.ys.shape
# Out:
# ((10000,), (10000,))

# %%
y.plot()

# %%
y.ys.max(), y.ys.mean(), y.ys.std()
# Out:
# (6.242357776479565, -39.41584147494993, 23.24868034337374)

# %%
sy= y.make_spectrum()
sy.plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
sy.make_integrated_spectrum().plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
sy.make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1b5d83cf91b4> in <module>
# ----> 1 sy.make_integrated_spectrum().estimate_slope()
#
# ~\Anaconda3\envs\grace87\lib\site-packages\thinkdsp.py in estimate_slope(self, low, high)
#     478         x = np.log(self.fs[low:high])
#     479         y = np.log(self.cs[low:high])
# --> 480         t = scipy.stats.linregress(x,y)
#     481         return t
#     482
#
# ~\Anaconda3\envs\grace87\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      93
#      94     if x.size == 0 or y.size == 0:
# ---> 95         raise ValueError("Inputs must not be empty.")
#      96
#      97     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()

# %%
z.make_spectrum().make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-82fa107f3ce5> in <module>
# ----> 1 z.make_spectrum().make_integrated_spectrum().estimate_slope()
#
# ~\Anaconda3\envs\grace87\lib\site-packages\thinkdsp.py in estimate_slope(self, low, high)
#     478         x = np.log(self.fs[low:high])
#     479         y = np.log(self.cs[low:high])
# --> 480         t = scipy.stats.linregress(x,y)
#     481         return t
#     482
#
# ~\Anaconda3\envs\grace87\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      93
#      94     if x.size == 0 or y.size == 0:
# ---> 95         raise ValueError("Inputs must not be empty.")
#      96
#      97     n = len(x)
#
# ValueError: Inputs must not be empty.
